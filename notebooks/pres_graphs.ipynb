# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

models = ['dummy', 'svd', 'knn_basic', 'knn_baseline', 'svdpp']
scores = [dummy, best_svd, best_knn_basic, best_knn_baseline, best_svdpp]

plt.bar(models, scores)
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Model Comparison')
plt.xticks(rotation=45)
plt.savefig('../images/model_comparison.png')
plt.show()
